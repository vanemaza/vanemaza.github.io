# %%
#Funciones requeridas: data(), str(), ncol(), nrow(), dim(), head(), tail(), summary

#DATA FRAME FLIGHTS
install.packages(nycf)

data.frame("flights")

str(flights)

ncol(flights)

nrow(flights)

dim(flights)

View(flights)

head(flights)

tail(flights)

summary(flights)

#DATA FRAME WEATHER

data.frame("weather")

str(weather)

ncol(weather)

nrow(weather)

dim(weather)

View(weather)

head(weather)

tail(weather)

summary(weather)

#DATA FRAME AIRPORTS

data.frame("airports")

str(airports)

ncol(airports)

nrow(airports)

dim(airports)

View(airports)

head(airports)

tail(airports)

summary(airports)

#DATA FRAME PLANES

data.frame("planes")

str(planes)

ncol(planes)

nrow(planes)

dim(planes)

View(planes)

head(planes)

tail(planes)

summary(planes)

#DATA FRAME AIRLINES
data.frame("airlines")

str(airlines)

ncol(airlines)

nrow(airlines)

dim(airlines)

View(airlines)

head(airlines)

tail(airlines)

summary(airlines)

#Consulta el data frame flights para recordar su contenido.

View(flights)

#Encuentra los datos descriptivos del data frame flights. Identifica la media de las distancias recorridas en millas. media, mediana.
descripcion <- select(flights, distance)
descripcion
summary(descripcion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 #Funciones requeridas: data(), str(), ncol(), nrow(), dim(), head(), tail(), summary
#       2
#       3 #DATA FRAME FLIGHTS
# ----> 4 install.packages(nycf)
#       6 data.frame("flights")
#       8 str(flights)
#
# NameError: name 'install' is not defined
